# %% [markdown]
# FLIGHT PRICE PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib 
# %matplotlib inline

# %%
df=pd.read_excel(r'C:\Users\Welcome\Downloads\Data_Train.xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
test=pd.read_excel(r'C:\Users\Welcome\Downloads\Test_set.xlsx')

# %%
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
final=pd.concat([df,test],ignore_index=True)

# %%
final
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %%
final.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# we should split the values of dates in monthes , date and year

# %%
final['Date']=final['Date_of_Journey'].str.split('/').str[0]

# %%
final['Month']=final['Date_of_Journey'].str.split('/').str[1]

# %%
final['Year']=final['Date_of_Journey'].str.split('/').str[2]

# %%
final
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
final.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13349          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13350             IndiGo   Kolkata    Banglore              CCU → BLR
# 13351        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13352          Air India     Delhi      Cochin        DEL → BOM → COK
# 13353  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price  \
# ...

# %%
final.drop('Additional_Info',axis=1,inplace=True)

# %%
final
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13349          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13350             IndiGo   Kolkata    Banglore              CCU → BLR
# 13351        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13352          Air India     Delhi      Cochin        DEL → BOM → COK
# 13353  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops    Price Date Month  Year
# ...

# %%
final['Arrival_Time']
# Out:
# 0        01:10 22 Mar
# 1               13:15
# 2        04:25 10 Jun
# 3               23:30
# 4               21:35
#              ...
# 13349    20:25 07 Jun
# 13350           16:55
# 13351    04:25 07 Mar
# 13352           19:15
# 13353           19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final['Time']=final['Arrival_Time'].str.split(' ').str[0]

# %%
final
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13349          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13350             IndiGo   Kolkata    Banglore              CCU → BLR
# 13351        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13352          Air India     Delhi      Cochin        DEL → BOM → COK
# 13353  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops    Price Date Month  Year  \
# ...

# %%
final.drop('Arrival_Time',axis=1,inplace=True)

# %%
final.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops    Price Date Month  Year   Time
# 0    non-stop   3897.0   24    03  2019  01:10
# 1     2 stops   7662.0    1    05  2019  13:15
# 2     2 stops  13882.0    9    06  2019  04:25
# 3      1 stop   6218.0   12    05  2019  23:30
# 4      1 stop  13302.0   01    03  2019  21:35

# %%
final.isnull().sum()
# Out:
# Airline           0
# Source            0
# Destination       0
# Route             1
# Dep_Time          0
# Duration          0
# Total_Stops       1
# Price          2671
# Date              0
# Month             0
# Year              0
# Time              0
# dtype: int64

# %%
final['Price'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13349     True
# 13350     True
# 13351     True
# 13352     True
# 13353     True
# Name: Price, Length: 13354, dtype: bool

# %%
final['Price'].mode()[0]
# Out:
# np.float64(10262.0)

# %%
final['Price']=final['Price'].fillna(final['Price'].mode()[0])

# %%
final['Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
final
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13349          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13350             IndiGo   Kolkata    Banglore              CCU → BLR
# 13351        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13352          Air India     Delhi      Cochin        DEL → BOM → COK
# 13353  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Dep_Time Duration Total_Stops    Price Date Month  Year   Time
# ...

# %%
final['Total_Stops']=final['Total_Stops'].fillna(final['Total_Stops'].mode()[0])

# %%
final['Route']=final['Route'].fillna(final['Route'].mode()[0])

# %%
final.drop('Route',axis=1,inplace=True)

# %%
final
# Out:
#                  Airline    Source Destination Dep_Time Duration Total_Stops  \
# 0                 IndiGo  Banglore   New Delhi    22:20   2h 50m    non-stop
# 1              Air India   Kolkata    Banglore    05:50   7h 25m     2 stops
# 2            Jet Airways     Delhi      Cochin    09:25      19h     2 stops
# 3                 IndiGo   Kolkata    Banglore    18:05   5h 25m      1 stop
# 4                 IndiGo  Banglore   New Delhi    16:50   4h 45m      1 stop
# ...                  ...       ...         ...      ...      ...         ...
# 13349          Air India   Kolkata    Banglore    20:30  23h 55m      1 stop
# 13350             IndiGo   Kolkata    Banglore    14:20   2h 35m    non-stop
# 13351        Jet Airways     Delhi      Cochin    21:50   6h 35m      1 stop
# 13352          Air India     Delhi      Cochin    04:00  15h 15m      1 stop
# 13353  Multiple carriers     Delhi      Cochin    04:55  14h 20m      1 stop
#
#          Price Date Month  Year   Time
# ...

# %%
final['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
final['Total_Stops']=final['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4})

# %%
final
# Out:
#                  Airline    Source Destination Dep_Time Duration  Total_Stops  \
# 0                 IndiGo  Banglore   New Delhi    22:20   2h 50m            0
# 1              Air India   Kolkata    Banglore    05:50   7h 25m            2
# 2            Jet Airways     Delhi      Cochin    09:25      19h            2
# 3                 IndiGo   Kolkata    Banglore    18:05   5h 25m            1
# 4                 IndiGo  Banglore   New Delhi    16:50   4h 45m            1
# ...                  ...       ...         ...      ...      ...          ...
# 13349          Air India   Kolkata    Banglore    20:30  23h 55m            1
# 13350             IndiGo   Kolkata    Banglore    14:20   2h 35m            0
# 13351        Jet Airways     Delhi      Cochin    21:50   6h 35m            1
# 13352          Air India     Delhi      Cochin    04:00  15h 15m            1
# 13353  Multiple carriers     Delhi      Cochin    04:55  14h 20m            1
#
# ...

# %%
final['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
final['Destination']=final['Destination'].map({'New Delhi':1, 'Banglore':2, 'Cochin':3, 'Kolkata':4, 'Delhi':5, 'Hyderabad':6})

# %%
final.head()
# Out:
#        Airline    Source  Destination Dep_Time Duration  Total_Stops    Price  \
# 0       IndiGo  Banglore            1    22:20   2h 50m            0   3897.0
# 1    Air India   Kolkata            2    05:50   7h 25m            2   7662.0
# 2  Jet Airways     Delhi            3    09:25      19h            2  13882.0
# 3       IndiGo   Kolkata            2    18:05   5h 25m            1   6218.0
# 4       IndiGo  Banglore            1    16:50   4h 45m            1  13302.0
#
#   Date Month  Year   Time
# 0   24    03  2019  01:10
# 1    1    05  2019  13:15
# 2    9    06  2019  04:25
# 3   12    05  2019  23:30
# 4   01    03  2019  21:35

# %%
final['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
final['Source']=final['Source'].map({ 'Banglore':2,  'Kolkata':4, 'Delhi':5, 'Chennai':7,'Mumbai':8})

# %%
final.head()
# Out:
#        Airline  Source  Destination Dep_Time Duration  Total_Stops    Price  \
# 0       IndiGo       2            1    22:20   2h 50m            0   3897.0
# 1    Air India       4            2    05:50   7h 25m            2   7662.0
# 2  Jet Airways       5            3    09:25      19h            2  13882.0
# 3       IndiGo       4            2    18:05   5h 25m            1   6218.0
# 4       IndiGo       2            1    16:50   4h 45m            1  13302.0
#
#   Date Month  Year   Time
# 0   24    03  2019  01:10
# 1    1    05  2019  13:15
# 2    9    06  2019  04:25
# 3   12    05  2019  23:30
# 4   01    03  2019  21:35

# %%
final['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          4746
# IndiGo                               2564
# Air India                            2192
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
final['Airline']=labelencoder.fit_transform(final['Airline'])

# %%
final.head()
# Out:
#    Airline  Source  Destination Dep_Time Duration  Total_Stops    Price Date  \
# 0        3       2            1    22:20   2h 50m            0   3897.0   24
# 1        1       4            2    05:50   7h 25m            2   7662.0    1
# 2        4       5            3    09:25      19h            2  13882.0    9
# 3        3       4            2    18:05   5h 25m            1   6218.0   12
# 4        3       2            1    16:50   4h 45m            1  13302.0   01
#
#   Month  Year   Time
# 0    03  2019  01:10
# 1    05  2019  13:15
# 2    06  2019  04:25
# 3    05  2019  23:30
# 4    03  2019  21:35

# %%
final['Airline'].value_counts()
# Out:
# Airline
# 4     4746
# 3     2564
# 1     2192
# 6     1543
# 8     1026
# 10     608
# 0      405
# 2      240
# 7       16
# 5        8
# 11       5
# 9        1
# Name: count, dtype: int64

# %%
labelencoder.classes_
# Out:
# array(['Air Asia', 'Air India', 'GoAir', 'IndiGo', 'Jet Airways',
#        'Jet Airways Business', 'Multiple carriers',
#        'Multiple carriers Premium economy', 'SpiceJet', 'Trujet',
#        'Vistara', 'Vistara Premium economy'], dtype=object)

# %% [markdown]
# IndiGo                               2564
# Air India                            2192
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
